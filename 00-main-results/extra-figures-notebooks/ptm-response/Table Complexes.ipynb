# %% [markdown]
# This notebook generates the table with information about protein complexes

# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
import os
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from tqdm import tqdm
sns.set_palette('Dark2')
sns.set_style({'axes.axisbelow': True, 'axes.edgecolor': '.15', 'axes.facecolor': 'white',
               'axes.grid': True, 'axes.labelcolor': '.15', 'axes.linewidth': 1.25, 
               'figure.facecolor': 'white', 'font.family': ['sans-serif'], 'grid.color': '.15',
               'grid.linestyle': ':', 'grid.alpha': .5, 'image.cmap': 'Greys', 
               'legend.frameon': False, 'legend.numpoints': 1, 'legend.scatterpoints': 1,
               'lines.solid_capstyle': 'round', 'axes.spines.right': False, 'axes.spines.top': False,  
               'text.color': '.15',  'xtick.top': False, 'ytick.right': False, 'xtick.color': '.15',
               'xtick.direction': 'out', 'xtick.major.size': 6, 'xtick.minor.size': 3,
               'ytick.color': '.15', 'ytick.direction': 'out', 'ytick.major.size': 6,'ytick.minor.size': 3})
sns.set_context('paper')

#http://phyletica.org/matplotlib-fonts/
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %% [markdown]
# Set up

# %%
from snapanalysis.config import OUTPUT_DIRECTORY as MAIN_OUTPUT_DIRECTORY
OUTPUT_DIRECTORY = os.path.join(MAIN_OUTPUT_DIRECTORY, 'ptm-response')

if not os.path.isdir(OUTPUT_DIRECTORY):
    os.makedirs(OUTPUT_DIRECTORY)
    
def output_path(basename):
    return os.path.join(OUTPUT_DIRECTORY, basename)

# %%
from snapanalysis.external.complexes.curated import OUTPUT_FILE as COMPLEXES_FILE

curated_complexes = pd.read_hdf(COMPLEXES_FILE, 'curated_complexes')

# %% [markdown]
# Data from camera

# %%
from snapanalysis.models.ptm_response.main import OUTPUT_FILE as PTM_RESPONSE_FILE

from snapanalysis.models.ptm_response.main import PREDICTOR_ORDER
predictors = PREDICTOR_ORDER

limma_results = pd.read_hdf(PTM_RESPONSE_FILE, '/ptm_stats/joint_limma_stats')
predictors_from_limma = limma_results.reset_index()['predictor'].unique()
assert all(p in predictors_from_limma for p in predictors)
assert all(p in predictors for p in predictors_from_limma)


with pd.HDFStore(PTM_RESPONSE_FILE, 'r') as store: 
    enrichment_complexes = store['/ptm_stats/joint_camera_complexes']

# %%
palette = sns.color_palette('RdBu_r', 9).as_hex()
blue = palette[0]
red = palette[-1]
white = palette[4]

sns.palplot([blue, white, red])

# %%
vmin = -1.5
vmax = 1.5

# %%
from snapanalysis.models.ptm_response.main import ENRICHMENT_FDR_THRESHOLD
ENRICHMENT_FDR_THRESHOLD
# Out:
# 0.01

# %%
ABS_EFFECT_THRESHOLD = 0.25

# %%
enrichment_complexes
# Out:
#                                                              NGenes Direction  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                         6.0        Up
#           ncPRC1.6                                             15.0        Up
#           SIN3A/B (exclusive subunits)                          9.0        Up
#           PRC1                                                  9.0        Up
#           CAF-1                                                 3.0        Up
#           BHC                                                   8.0        Up
#           HUSH                                                  4.0        Up
#           SIN3A/B                                              18.0        Up
#           KAP1-SETDB1-DNMT1-ZNF304                              3.0        Up
#           SF3B                                                  7.0      Down
#           INO80 (exclusive subunits)                           11.0        Up
#           KAP1-HP1                                              3.0        Up
#           B-MYB-MuvB                                            6.0        Up
#           SRCAP                                                 9.0      Down
#           ORC                                                   5.0        Up
#           B-MYB-MuvB (exclusive subunits)                       5.0        Up
#           ASAP                                                  6.0      Down
#           Integrator (exclusive subunits)                      13.0        Up
#           THO                                                   6.0      Down
#           Integrator                                           14.0        Up
#           PRC1 (exclusive subunits)                             6.0        Up
#           PR-DUB                                                5.0        Up
#           ncPRC1                                                5.0        Up
#           TREX                                                  9.0      Down
#           40S Ribosomal subunit                                29.0      Down
#           ncPRC1.1                                             11.0        Up
#           INO80                                                15.0        Up
#           Mediator                                             17.0        Up
#           NuA4 (exclusive subunits)                             6.0        Up
#           PRC2.1                                               12.0        Up
# ...                                                             ...       ...
# H3ac      Mitochondrial respiratory chain complex I             4.0        Up
#           ncPRC1.1 (exclusive subunits)                         5.0        Up
#           CKM                                                   3.0        Up
#           mCRD-poly(A)-bridging complex                         3.0      Down
#           TFIID (exclusive subunits)                            4.0        Up
#           RNA Pol II (exclusive subunits)                       6.0        Up
#           NSL (exclusive subunits)                              3.0        Up
#           Base Excision Repair Complex (exclusive subunits)     3.0      Down
#           VHL SCF-like                                          4.0        Up
#           XPC (exclusive subunits)                              3.0        Up
#           Fanconi Anemia                                        4.0        Up
#           PRC2.1 (exclusive subunits)                           5.0        Up
#           RNA Pol II                                           11.0        Up
#           B-MYB-MuvB (exclusive subunits)                       5.0        Up
#           CRL4-DDB2                                             4.0        Up
#           CDCA5-PDS5-Cohesin                                    3.0        Up
#           VCB                                                   3.0        Up
#           SCF                                                   6.0        Up
#           CRL4-DDB2 (exclusive subunits)                        3.0        Up
#           Condensin II                                          4.0        Up
#           B-WICH (exclusive subunits)                           3.0      Down
#           PTW/PP1                                               6.0        Up
#           OST                                                   4.0        Up
#           PTW/PP1 (exclusive subunits)                          5.0        Up
#           RNA Pol III                                           6.0      Down
#           RNA exosome                                          10.0        Up
#           SCF (exclusive subunits)                              4.0        Up
#           Base Excision Repair Complex                          4.0      Down
#           Nuclear pore complex                                 22.0      Down
#           Nuclear pore complex (exclusive subunits)            20.0      Down
#
#                                                                    PValue  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                      3.348327e-09
#           ncPRC1.6                                           4.996852e-08
#           SIN3A/B (exclusive subunits)                       1.235410e-06
#           PRC1                                               5.527297e-06
#           CAF-1                                              7.327983e-06
#           BHC                                                8.156250e-06
#           HUSH                                               1.332954e-05
#           SIN3A/B                                            4.177514e-05
#           KAP1-SETDB1-DNMT1-ZNF304                           1.007542e-04
#           SF3B                                               1.128506e-04
#           INO80 (exclusive subunits)                         1.358568e-04
#           KAP1-HP1                                           1.495414e-04
#           B-MYB-MuvB                                         2.839887e-04
#           SRCAP                                              5.154156e-04
#           ORC                                                5.573002e-04
#           B-MYB-MuvB (exclusive subunits)                    5.829568e-04
#           ASAP                                               7.199265e-04
#           Integrator (exclusive subunits)                    7.563552e-04
#           THO                                                7.781227e-04
#           Integrator                                         1.213460e-03
#           PRC1 (exclusive subunits)                          1.291609e-03
#           PR-DUB                                             1.548879e-03
#           ncPRC1                                             2.036580e-03
#           TREX                                               2.590671e-03
#           40S Ribosomal subunit                              3.927548e-03
#           ncPRC1.1                                           4.142518e-03
#           INO80                                              4.261622e-03
#           Mediator                                           4.372266e-03
#           NuA4 (exclusive subunits)                          6.019978e-03
#           PRC2.1                                             8.444936e-03
# ...                                                                   ...
# H3ac      Mitochondrial respiratory chain complex I          3.651924e-01
#           ncPRC1.1 (exclusive subunits)                      3.725542e-01
#           CKM                                                3.840329e-01
#           mCRD-poly(A)-bridging complex                      3.885777e-01
#           TFIID (exclusive subunits)                         4.024965e-01
#           RNA Pol II (exclusive subunits)                    4.073290e-01
#           NSL (exclusive subunits)                           4.087440e-01
#           Base Excision Repair Complex (exclusive subunits)  4.131566e-01
#           VHL SCF-like                                       4.215831e-01
#           XPC (exclusive subunits)                           4.404277e-01
#           Fanconi Anemia                                     4.514898e-01
#           PRC2.1 (exclusive subunits)                        4.648878e-01
#           RNA Pol II                                         4.688270e-01
#           B-MYB-MuvB (exclusive subunits)                    5.015839e-01
#           CRL4-DDB2                                          5.104488e-01
#           CDCA5-PDS5-Cohesin                                 5.314745e-01
#           VCB                                                5.757043e-01
#           SCF                                                6.622833e-01
#           CRL4-DDB2 (exclusive subunits)                     6.958875e-01
#           Condensin II                                       7.159291e-01
#           B-WICH (exclusive subunits)                        7.527622e-01
#           PTW/PP1                                            8.320803e-01
#           OST                                                8.806227e-01
#           PTW/PP1 (exclusive subunits)                       9.008851e-01
#           RNA Pol III                                        9.046943e-01
#           RNA exosome                                        9.305148e-01
#           SCF (exclusive subunits)                           9.352661e-01
#           Base Excision Repair Complex                       9.578881e-01
#           Nuclear pore complex                               9.668068e-01
#           Nuclear pore complex (exclusive subunits)          9.775688e-01
#
#                                                                       FDR  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                      4.386309e-07
#           ncPRC1.6                                           3.272938e-06
#           SIN3A/B (exclusive subunits)                       5.394624e-05
#           PRC1                                               1.780781e-04
#           CAF-1                                              1.780781e-04
#           BHC                                                1.780781e-04
#           HUSH                                               2.494529e-04
#           SIN3A/B                                            6.840679e-04
#           KAP1-SETDB1-DNMT1-ZNF304                           1.466533e-03
#           SF3B                                               1.478343e-03
#           INO80 (exclusive subunits)                         1.617931e-03
#           KAP1-HP1                                           1.632494e-03
#           B-MYB-MuvB                                         2.861733e-03
#           SRCAP                                              4.772959e-03
#           ORC                                                4.772959e-03
#           B-MYB-MuvB (exclusive subunits)                    4.772959e-03
#           ASAP                                               5.364951e-03
#           Integrator (exclusive subunits)                    5.364951e-03
#           THO                                                5.364951e-03
#           Integrator                                         7.948165e-03
#           PRC1 (exclusive subunits)                          8.057179e-03
#           PR-DUB                                             9.222872e-03
#           ncPRC1                                             1.159965e-02
#           TREX                                               1.414075e-02
#           40S Ribosomal subunit                              2.045596e-02
#           ncPRC1.1                                           2.045596e-02
#           INO80                                              2.045596e-02
#           Mediator                                           2.045596e-02
#           NuA4 (exclusive subunits)                          2.719369e-02
#           PRC2.1                                             3.687622e-02
# ...                                                                   ...
# H3ac      Mitochondrial respiratory chain complex I          4.710981e-01
#           ncPRC1.1 (exclusive subunits)                      4.758365e-01
#           CKM                                                4.856887e-01
#           mCRD-poly(A)-bridging complex                      4.866652e-01
#           TFIID (exclusive subunits)                         4.974337e-01
#           RNA Pol II (exclusive subunits)                    4.974337e-01
#           NSL (exclusive subunits)                           4.974337e-01
#           Base Excision Repair Complex (exclusive subunits)  4.981047e-01
#           VHL SCF-like                                       5.035576e-01
#           XPC (exclusive subunits)                           5.212402e-01
#           Fanconi Anemia                                     5.294744e-01
#           PRC2.1 (exclusive subunits)                        5.399883e-01
#           RNA Pol II                                         5.399883e-01
#           B-MYB-MuvB (exclusive subunits)                    5.726046e-01
#           CRL4-DDB2                                          5.776131e-01
#           CDCA5-PDS5-Cohesin                                 5.961758e-01
#           VCB                                                6.402229e-01
#           SCF                                                7.302098e-01
#           CRL4-DDB2 (exclusive subunits)                     7.607584e-01
#           Condensin II                                       7.760912e-01
#           B-WICH (exclusive subunits)                        8.092194e-01
#           PTW/PP1                                            8.870939e-01
#           OST                                                9.311502e-01
#           PTW/PP1 (exclusive subunits)                       9.411739e-01
#           RNA Pol III                                        9.411739e-01
#           RNA exosome                                        9.575343e-01
#           SCF (exclusive subunits)                           9.575343e-01
#           Base Excision Repair Complex                       9.729730e-01
#           Nuclear pore complex                               9.743600e-01
#           Nuclear pore complex (exclusive subunits)          9.775688e-01
#
#                                                              mean_logFC  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                        0.849107
#           ncPRC1.6                                             0.435135
#           SIN3A/B (exclusive subunits)                         0.229611
#           PRC1                                                 0.251455
#           CAF-1                                                 1.86441
#           BHC                                                  0.412906
#           HUSH                                                 0.878475
#           SIN3A/B                                              0.176159
#           KAP1-SETDB1-DNMT1-ZNF304                              1.23289
#           SF3B                                                -0.105004
#           INO80 (exclusive subunits)                           0.416366
#           KAP1-HP1                                              2.17175
#           B-MYB-MuvB                                           0.248151
#           SRCAP                                              -0.0613258
#           ORC                                                    1.1861
#           B-MYB-MuvB (exclusive subunits)                      0.245946
#           ASAP                                                -0.139175
#           Integrator (exclusive subunits)                      0.153446
#           THO                                                -0.0900677
#           Integrator                                           0.146891
#           PRC1 (exclusive subunits)                            0.254266
#           PR-DUB                                               0.325304
#           ncPRC1                                               0.183471
#           TREX                                               -0.0519582
#           40S Ribosomal subunit                              -0.0184955
#           ncPRC1.1                                             0.225864
#           INO80                                                0.313268
#           Mediator                                              0.15811
#           NuA4 (exclusive subunits)                            0.228422
#           PRC2.1                                               0.287373
# ...                                                                 ...
# H3ac      Mitochondrial respiratory chain complex I            0.307783
#           ncPRC1.1 (exclusive subunits)                        0.109856
#           CKM                                                  0.570646
#           mCRD-poly(A)-bridging complex                      0.00403981
#           TFIID (exclusive subunits)                           0.892606
#           RNA Pol II (exclusive subunits)                       0.14123
#           NSL (exclusive subunits)                             0.742837
#           Base Excision Repair Complex (exclusive subunits) -0.00150444
#           VHL SCF-like                                         0.195866
#           XPC (exclusive subunits)                             0.130255
#           Fanconi Anemia                                       0.274519
#           PRC2.1 (exclusive subunits)                          0.243018
#           RNA Pol II                                           0.116759
#           B-MYB-MuvB (exclusive subunits)                      0.269117
#           CRL4-DDB2                                            0.253116
#           CDCA5-PDS5-Cohesin                                   0.270225
#           VCB                                                  0.171522
#           SCF                                                  0.158363
#           CRL4-DDB2 (exclusive subunits)                       0.247856
#           Condensin II                                         0.188178
#           B-WICH (exclusive subunits)                          0.122719
#           PTW/PP1                                             0.0830675
#           OST                                                   0.12804
#           PTW/PP1 (exclusive subunits)                        0.0706154
#           RNA Pol III                                         0.0587841
#           RNA exosome                                         0.0623067
#           SCF (exclusive subunits)                             0.135347
#           Base Excision Repair Complex                         0.194261
#           Nuclear pore complex                                 0.102641
#           Nuclear pore complex (exclusive subunits)            0.105943
#
#                                                               mean_CI.L  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                        0.634297
#           ncPRC1.6                                             0.238182
#           SIN3A/B (exclusive subunits)                         0.108907
#           PRC1                                                0.0870596
#           CAF-1                                                 1.51666
#           BHC                                                   0.25004
#           HUSH                                                 0.615936
#           SIN3A/B                                             0.0378029
#           KAP1-SETDB1-DNMT1-ZNF304                              0.92361
#           SF3B                                                -0.245177
#           INO80 (exclusive subunits)                           0.111745
#           KAP1-HP1                                              1.61888
#           B-MYB-MuvB                                           0.105002
#           SRCAP                                               -0.152724
#           ORC                                                  0.541325
#           B-MYB-MuvB (exclusive subunits)                      0.110147
#           ASAP                                                -0.295493
#           Integrator (exclusive subunits)                     0.0082542
#           THO                                                 -0.200189
#           Integrator                                        -0.00290067
#           PRC1 (exclusive subunits)                           0.0673815
#           PR-DUB                                                0.11094
#           ncPRC1                                              0.0571123
#           TREX                                                -0.177137
#           40S Ribosomal subunit                               -0.209855
#           ncPRC1.1                                             0.107522
#           INO80                                               0.0478228
#           Mediator                                           -0.0652521
#           NuA4 (exclusive subunits)                           0.0459118
#           PRC2.1                                             -0.0199971
# ...                                                                 ...
# H3ac      Mitochondrial respiratory chain complex I           0.0623592
#           ncPRC1.1 (exclusive subunits)                       -0.013182
#           CKM                                                  0.120063
#           mCRD-poly(A)-bridging complex                       -0.157683
#           TFIID (exclusive subunits)                           0.119837
#           RNA Pol II (exclusive subunits)                    0.00811966
#           NSL (exclusive subunits)                             0.154736
#           Base Excision Repair Complex (exclusive subunits)   -0.107686
#           VHL SCF-like                                       0.00869037
#           XPC (exclusive subunits)                            0.0110132
#           Fanconi Anemia                                      0.0432904
#           PRC2.1 (exclusive subunits)                       -0.00734728
#           RNA Pol II                                         -0.0127855
#           B-MYB-MuvB (exclusive subunits)                    0.00950693
#           CRL4-DDB2                                           0.0210794
#           CDCA5-PDS5-Cohesin                                -0.00841215
#           VCB                                                -0.0246728
#           SCF                                                -0.0171001
#           CRL4-DDB2 (exclusive subunits)                    -0.00815413
#           Condensin II                                         -0.06762
#           B-WICH (exclusive subunits)                        -0.0612849
#           PTW/PP1                                            -0.0411291
#           OST                                                -0.0649948
#           PTW/PP1 (exclusive subunits)                        -0.047295
#           RNA Pol III                                        -0.0722372
#           RNA exosome                                         -0.159086
#           SCF (exclusive subunits)                           -0.0521935
#           Base Excision Repair Complex                        0.0599209
#           Nuclear pore complex                               -0.0900736
#           Nuclear pore complex (exclusive subunits)          -0.0909846
#
#                                                              mean_CI.R  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                        1.06392
#           ncPRC1.6                                            0.632088
#           SIN3A/B (exclusive subunits)                        0.350316
#           PRC1                                                 0.41585
#           CAF-1                                                2.21216
#           BHC                                                 0.575772
#           HUSH                                                 1.14101
#           SIN3A/B                                             0.314515
#           KAP1-SETDB1-DNMT1-ZNF304                             1.54216
#           SF3B                                               0.0351686
#           INO80 (exclusive subunits)                          0.720987
#           KAP1-HP1                                             2.72463
#           B-MYB-MuvB                                            0.3913
#           SRCAP                                              0.0300723
#           ORC                                                  1.83087
#           B-MYB-MuvB (exclusive subunits)                     0.381746
#           ASAP                                               0.0171436
#           Integrator (exclusive subunits)                     0.298638
#           THO                                                0.0200535
#           Integrator                                          0.296682
#           PRC1 (exclusive subunits)                           0.441151
#           PR-DUB                                              0.539668
#           ncPRC1                                               0.30983
#           TREX                                               0.0732206
#           40S Ribosomal subunit                               0.172864
#           ncPRC1.1                                            0.344207
#           INO80                                               0.578713
#           Mediator                                            0.381472
#           NuA4 (exclusive subunits)                           0.410933
#           PRC2.1                                              0.594742
# ...                                                                ...
# H3ac      Mitochondrial respiratory chain complex I           0.553207
#           ncPRC1.1 (exclusive subunits)                       0.232893
#           CKM                                                  1.02123
#           mCRD-poly(A)-bridging complex                       0.165763
#           TFIID (exclusive subunits)                           1.66538
#           RNA Pol II (exclusive subunits)                      0.27434
#           NSL (exclusive subunits)                             1.33094
#           Base Excision Repair Complex (exclusive subunits)   0.104677
#           VHL SCF-like                                        0.383042
#           XPC (exclusive subunits)                            0.249497
#           Fanconi Anemia                                      0.505747
#           PRC2.1 (exclusive subunits)                         0.493383
#           RNA Pol II                                          0.246303
#           B-MYB-MuvB (exclusive subunits)                     0.528727
#           CRL4-DDB2                                           0.485154
#           CDCA5-PDS5-Cohesin                                  0.548862
#           VCB                                                 0.367718
#           SCF                                                 0.333825
#           CRL4-DDB2 (exclusive subunits)                      0.503867
#           Condensin II                                        0.443975
#           B-WICH (exclusive subunits)                         0.306723
#           PTW/PP1                                             0.207264
#           OST                                                 0.321074
#           PTW/PP1 (exclusive subunits)                        0.188526
#           RNA Pol III                                         0.189805
#           RNA exosome                                         0.283699
#           SCF (exclusive subunits)                            0.322888
#           Base Excision Repair Complex                        0.328602
#           Nuclear pore complex                                0.295355
#           Nuclear pore complex (exclusive subunits)           0.302871
#
#                                                             mean_AveExpr  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                         0.335809
#           ncPRC1.6                                             0.0493912
#           SIN3A/B (exclusive subunits)                          0.199731
#           PRC1                                                  0.952773
#           CAF-1                                                  1.17732
#           BHC                                                   0.221205
#           HUSH                                                  0.609998
#           SIN3A/B                                               0.260388
#           KAP1-SETDB1-DNMT1-ZNF304                               0.48333
#           SF3B                                                  0.033141
#           INO80 (exclusive subunits)                           0.0944894
#           KAP1-HP1                                               1.46345
#           B-MYB-MuvB                                            0.216309
#           SRCAP                                                 -0.40798
#           ORC                                                    2.61108
#           B-MYB-MuvB (exclusive subunits)                       0.083194
#           ASAP                                                 0.0299068
#           Integrator (exclusive subunits)                      0.0126119
#           THO                                                 -0.0132042
#           Integrator                                           0.0218912
#           PRC1 (exclusive subunits)                              1.14383
#           PR-DUB                                                0.337153
#           ncPRC1                                                0.121775
#           TREX                                               -0.00259699
#           40S Ribosomal subunit                               -0.0296365
#           ncPRC1.1                                              -0.52952
#           INO80                                              -0.00309983
#           Mediator                                             0.0700805
#           NuA4 (exclusive subunits)                            0.0461168
#           PRC2.1                                                0.210958
# ...                                                                  ...
# H3ac      Mitochondrial respiratory chain complex I            0.0311183
#           ncPRC1.1 (exclusive subunits)                         0.103957
#           CKM                                                   0.474355
#           mCRD-poly(A)-bridging complex                        0.0479513
#           TFIID (exclusive subunits)                             1.90024
#           RNA Pol II (exclusive subunits)                       0.227907
#           NSL (exclusive subunits)                              0.438702
#           Base Excision Repair Complex (exclusive subunits)   -0.0660697
#           VHL SCF-like                                          0.102599
#           XPC (exclusive subunits)                              0.104915
#           Fanconi Anemia                                        0.092002
#           PRC2.1 (exclusive subunits)                          -0.877939
#           RNA Pol II                                            0.192364
#           B-MYB-MuvB (exclusive subunits)                       0.165454
#           CRL4-DDB2                                             0.265779
#           CDCA5-PDS5-Cohesin                                    0.186229
#           VCB                                                  0.0427769
#           SCF                                                   0.174877
#           CRL4-DDB2 (exclusive subunits)                         0.26035
#           Condensin II                                        0.00842319
#           B-WICH (exclusive subunits)                          0.0239012
#           PTW/PP1                                               0.200714
#           OST                                                 -0.0680289
#           PTW/PP1 (exclusive subunits)                          0.153653
#           RNA Pol III                                           0.119703
#           RNA exosome                                          0.0603296
#           SCF (exclusive subunits)                              0.145064
#           Base Excision Repair Complex                          0.135555
#           Nuclear pore complex                                 0.0230869
#           Nuclear pore complex (exclusive subunits)            0.0319949
#
#                                                                mean_t  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                       11.2397
#           ncPRC1.6                                            6.22172
#           SIN3A/B (exclusive subunits)                        4.52591
#           PRC1                                                4.84648
#           CAF-1                                               15.0551
#           BHC                                                 8.01459
#           HUSH                                                7.32464
#           SIN3A/B                                             3.04936
#           KAP1-SETDB1-DNMT1-ZNF304                            9.84516
#           SF3B                                               -2.02126
#           INO80 (exclusive subunits)                          3.03286
#           KAP1-HP1                                            7.44629
#           B-MYB-MuvB                                          3.87901
#           SRCAP                                              -1.45227
#           ORC                                                 4.04811
#           B-MYB-MuvB (exclusive subunits)                     4.02627
#           ASAP                                               -1.83967
#           Integrator (exclusive subunits)                     2.58394
#           THO                                                -1.80687
#           Integrator                                          2.44523
#           PRC1 (exclusive subunits)                           4.12767
#           PR-DUB                                              3.77393
#           ncPRC1                                              4.36592
#           TREX                                               -1.17128
#           40S Ribosomal subunit                             -0.378219
#           ncPRC1.1                                            3.47876
#           INO80                                               2.23025
#           Mediator                                            2.11065
#           NuA4 (exclusive subunits)                           2.90169
#           PRC2.1                                              2.31789
# ...                                                               ...
# H3ac      Mitochondrial respiratory chain complex I           2.78634
#           ncPRC1.1 (exclusive subunits)                       2.80886
#           CKM                                                 3.27414
#           mCRD-poly(A)-bridging complex                     -0.463855
#           TFIID (exclusive subunits)                          2.72514
#           RNA Pol II (exclusive subunits)                     2.36315
#           NSL (exclusive subunits)                            2.99183
#           Base Excision Repair Complex (exclusive subunits) -0.334818
#           VHL SCF-like                                        2.63465
#           XPC (exclusive subunits)                            2.83297
#           Fanconi Anemia                                      2.48273
#           PRC2.1 (exclusive subunits)                         2.36424
#           RNA Pol II                                          1.97011
#           B-MYB-MuvB (exclusive subunits)                     2.17069
#           CRL4-DDB2                                           2.34783
#           CDCA5-PDS5-Cohesin                                  2.71098
#           VCB                                                 2.34143
#           SCF                                                 1.84266
#           CRL4-DDB2 (exclusive subunits)                        1.959
#           Condensin II                                        1.87327
#           B-WICH (exclusive subunits)                        0.476444
#           PTW/PP1                                             1.44665
#           OST                                                 1.39202
#           PTW/PP1 (exclusive subunits)                        1.34519
#           RNA Pol III                                         1.06482
#           RNA exosome                                         1.35684
#           SCF (exclusive subunits)                            1.37188
#           Base Excision Repair Complex                        1.61747
#           Nuclear pore complex                                1.42608
#           Nuclear pore complex (exclusive subunits)           1.46547
#
#                                                             mean_P.Value  ...  \
# predictor Complex                                                         ...
# H3K9me3   ncPRC1.6 (exclusive subunits)                        0.0316113  ...
#           ncPRC1.6                                              0.114882  ...
#           SIN3A/B (exclusive subunits)                          0.011284  ...
#           PRC1                                                  0.108419  ...
#           CAF-1                                               0.00286562  ...
#           BHC                                                   0.171096  ...
#           HUSH                                               0.000987726  ...
#           SIN3A/B                                               0.074532  ...
#           KAP1-SETDB1-DNMT1-ZNF304                            0.00345532  ...
#           SF3B                                                  0.116892  ...
#           INO80 (exclusive subunits)                           0.0214367  ...
#           KAP1-HP1                                            0.00337294  ...
#           B-MYB-MuvB                                          0.00388529  ...
#           SRCAP                                                 0.314114  ...
#           ORC                                                  0.0025062  ...
#           B-MYB-MuvB (exclusive subunits)                     0.00294456  ...
#           ASAP                                                  0.127217  ...
#           Integrator (exclusive subunits)                       0.104227  ...
#           THO                                                   0.115357  ...
#           Integrator                                            0.134865  ...
#           PRC1 (exclusive subunits)                             0.158776  ...
#           PR-DUB                                               0.0114422  ...
#           ncPRC1                                                0.078243  ...
#           TREX                                                  0.237805  ...
#           40S Ribosomal subunit                                 0.523386  ...
#           ncPRC1.1                                              0.269778  ...
#           INO80                                                 0.196147  ...
#           Mediator                                               0.17042  ...
#           NuA4 (exclusive subunits)                             0.027224  ...
#           PRC2.1                                                0.136696  ...
# ...                                                                  ...  ...
# H3ac      Mitochondrial respiratory chain complex I            0.0571303  ...
#           ncPRC1.1 (exclusive subunits)                         0.169789  ...
#           CKM                                                   0.071729  ...
#           mCRD-poly(A)-bridging complex                         0.143203  ...
#           TFIID (exclusive subunits)                            0.176293  ...
#           RNA Pol II (exclusive subunits)                      0.0746231  ...
#           NSL (exclusive subunits)                             0.0732107  ...
#           Base Excision Repair Complex (exclusive subunits)      0.48053  ...
#           VHL SCF-like                                          0.143485  ...
#           XPC (exclusive subunits)                              0.117074  ...
#           Fanconi Anemia                                       0.0733641  ...
#           PRC2.1 (exclusive subunits)                           0.126348  ...
#           RNA Pol II                                            0.183626  ...
#           B-MYB-MuvB (exclusive subunits)                       0.047375  ...
#           CRL4-DDB2                                             0.158251  ...
#           CDCA5-PDS5-Cohesin                                    0.207677  ...
#           VCB                                                   0.190542  ...
#           SCF                                                   0.164531  ...
#           CRL4-DDB2 (exclusive subunits)                        0.210231  ...
#           Condensin II                                         0.0946064  ...
#           B-WICH (exclusive subunits)                         0.00419399  ...
#           PTW/PP1                                               0.223064  ...
#           OST                                                   0.194209  ...
#           PTW/PP1 (exclusive subunits)                          0.254572  ...
#           RNA Pol III                                           0.309289  ...
#           RNA exosome                                           0.263609  ...
#           SCF (exclusive subunits)                              0.232739  ...
#           Base Excision Repair Complex                          0.360397  ...
#           Nuclear pore complex                                  0.234413  ...
#           Nuclear pore complex (exclusive subunits)             0.221263  ...
#
#                                                             mean_confint_half_width  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                                     0.21481
#           ncPRC1.6                                                         0.196953
#           SIN3A/B (exclusive subunits)                                     0.120704
#           PRC1                                                             0.164395
#           CAF-1                                                            0.347753
#           BHC                                                              0.162866
#           HUSH                                                             0.262538
#           SIN3A/B                                                          0.138356
#           KAP1-SETDB1-DNMT1-ZNF304                                         0.309276
#           SF3B                                                             0.140173
#           INO80 (exclusive subunits)                                       0.304621
#           KAP1-HP1                                                         0.552873
#           B-MYB-MuvB                                                       0.143149
#           SRCAP                                                           0.0913981
#           ORC                                                              0.644772
#           B-MYB-MuvB (exclusive subunits)                                    0.1358
#           ASAP                                                             0.156318
#           Integrator (exclusive subunits)                                  0.145192
#           THO                                                              0.110121
#           Integrator                                                       0.149791
#           PRC1 (exclusive subunits)                                        0.186885
#           PR-DUB                                                           0.214364
#           ncPRC1                                                           0.126359
#           TREX                                                             0.125179
#           40S Ribosomal subunit                                             0.19136
#           ncPRC1.1                                                         0.118342
#           INO80                                                            0.265445
#           Mediator                                                         0.223362
#           NuA4 (exclusive subunits)                                         0.18251
#           PRC2.1                                                            0.30737
# ...                                                                             ...
# H3ac      Mitochondrial respiratory chain complex I                        0.245424
#           ncPRC1.1 (exclusive subunits)                                    0.123038
#           CKM                                                              0.450583
#           mCRD-poly(A)-bridging complex                                    0.161723
#           TFIID (exclusive subunits)                                       0.772769
#           RNA Pol II (exclusive subunits)                                   0.13311
#           NSL (exclusive subunits)                                         0.588101
#           Base Excision Repair Complex (exclusive subunits)                0.106182
#           VHL SCF-like                                                     0.187176
#           XPC (exclusive subunits)                                         0.119242
#           Fanconi Anemia                                                   0.231228
#           PRC2.1 (exclusive subunits)                                      0.250365
#           RNA Pol II                                                       0.129544
#           B-MYB-MuvB (exclusive subunits)                                   0.25961
#           CRL4-DDB2                                                        0.232037
#           CDCA5-PDS5-Cohesin                                               0.278637
#           VCB                                                              0.196195
#           SCF                                                              0.175463
#           CRL4-DDB2 (exclusive subunits)                                    0.25601
# ...
#           Nuclear pore complex (exclusive subunits)                 0.076175
#
#                                                             empirical_median_ci_left  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                                     0.852877
#           ncPRC1.6                                                          0.183013
#           SIN3A/B (exclusive subunits)                                      0.178071
#           PRC1                                                              0.203880
#           CAF-1                                                             1.630583
#           BHC                                                               0.133913
#           HUSH                                                              0.534392
#           SIN3A/B                                                           0.162103
#           KAP1-SETDB1-DNMT1-ZNF304                                          0.600757
#           SF3B                                                             -0.117538
#           INO80 (exclusive subunits)                                        0.303495
#           KAP1-HP1                                                          1.859490
#           B-MYB-MuvB                                                        0.185121
#           SRCAP                                                            -0.097311
#           ORC                                                               0.848406
#           B-MYB-MuvB (exclusive subunits)                                   0.176473
#           ASAP                                                             -0.184377
#           Integrator (exclusive subunits)                                   0.105644
#           THO                                                              -0.138340
#           Integrator                                                        0.103565
#           PRC1 (exclusive subunits)                                         0.187621
#           PR-DUB                                                            0.213886
#           ncPRC1                                                            0.106279
#           TREX                                                             -0.115146
#           40S Ribosomal subunit                                            -0.064240
#           ncPRC1.1                                                          0.029804
#           INO80                                                             0.229443
#           Mediator                                                          0.109035
#           NuA4 (exclusive subunits)                                         0.128087
#           PRC2.1                                                            0.173170
# ...                                                                              ...
# H3ac      Mitochondrial respiratory chain complex I                         0.188508
#           ncPRC1.1 (exclusive subunits)                                     0.045462
#           CKM                                                               0.170215
#           mCRD-poly(A)-bridging complex                                    -0.247941
#           TFIID (exclusive subunits)                                        0.559148
#           RNA Pol II (exclusive subunits)                                   0.079900
#           NSL (exclusive subunits)                                          0.223271
#           Base Excision Repair Complex (exclusive subunits)                -0.080280
#           VHL SCF-like                                                      0.114808
#           XPC (exclusive subunits)                                          0.066791
#           Fanconi Anemia                                                    0.148602
#           PRC2.1 (exclusive subunits)                                       0.110687
#           RNA Pol II                                                        0.059116
#           B-MYB-MuvB (exclusive subunits)                                   0.134050
#           CRL4-DDB2                                                         0.125236
#           CDCA5-PDS5-Cohesin                                                0.187680
#           VCB                                                               0.071590
#           SCF                                                               0.069616
#           CRL4-DDB2 (exclusive subunits)                                    0.048870
#           Condensin II                                                      0.105105
#           B-WICH (exclusive subunits)                                       0.068808
#           PTW/PP1                                                           0.029704
#           OST                                                               0.025709
#           PTW/PP1 (exclusive subunits)                                      0.013781
#           RNA Pol III                                                      -0.009501
#           RNA exosome                                                       0.027428
#           SCF (exclusive subunits)                                          0.013049
#           Base Excision Repair Complex                                     -0.045004
#           Nuclear pore complex                                              0.026631
#           Nuclear pore complex (exclusive subunits)                         0.022783
#
#                                                             empirical_median_ci_right  \
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                                      1.080185
#           ncPRC1.6                                                           0.300212
#           SIN3A/B (exclusive subunits)                                       0.279933
#           PRC1                                                               0.319279
#           CAF-1                                                              2.946132
#           BHC                                                                0.335547
#           HUSH                                                               0.870787
#           SIN3A/B                                                            0.244236
#           KAP1-SETDB1-DNMT1-ZNF304                                           1.486559
#           SF3B                                                              -0.041204
#           INO80 (exclusive subunits)                                         0.523898
#           KAP1-HP1                                                           3.296256
#           B-MYB-MuvB                                                         0.307952
#           SRCAP                                                             -0.020692
#           ORC                                                                1.525954
#           B-MYB-MuvB (exclusive subunits)                                    0.313131
#           ASAP                                                              -0.051567
#           Integrator (exclusive subunits)                                    0.196342
#           THO                                                               -0.041875
#           Integrator                                                         0.189238
#           PRC1 (exclusive subunits)                                          0.357632
#           PR-DUB                                                             0.404599
#           ncPRC1                                                             0.256127
#           TREX                                                              -0.017680
#           40S Ribosomal subunit                                              0.008255
#           ncPRC1.1                                                           0.142607
#           INO80                                                              0.449381
#           Mediator                                                           0.219456
#           NuA4 (exclusive subunits)                                          0.274269
#           PRC2.1                                                             0.423997
# ...                                                                               ...
# H3ac      Mitochondrial respiratory chain complex I                          0.445379
#           ncPRC1.1 (exclusive subunits)                                      0.169602
#           CKM                                                                0.910535
#           mCRD-poly(A)-bridging complex                                      0.129835
#           TFIID (exclusive subunits)                                         1.330819
#           RNA Pol II (exclusive subunits)                                    0.198052
#           NSL (exclusive subunits)                                           1.286612
#           Base Excision Repair Complex (exclusive subunits)                  0.082107
#           VHL SCF-like                                                       0.301008
#           XPC (exclusive subunits)                                           0.208361
#           Fanconi Anemia                                                     0.407342
#           PRC2.1 (exclusive subunits)                                        0.382159
#           RNA Pol II                                                         0.166001
#           B-MYB-MuvB (exclusive subunits)                                    0.404583
#           CRL4-DDB2                                                          0.373115
#           CDCA5-PDS5-Cohesin                                                 0.560526
#           VCB                                                                0.300163
#           SCF                                                                0.251880
#           CRL4-DDB2 (exclusive subunits)                                     0.423815
#           Condensin II                                                       0.392809
#           B-WICH (exclusive subunits)                                        0.409000
#           PTW/PP1                                                            0.141804
#           OST                                                                0.231166
#           PTW/PP1 (exclusive subunits)                                       0.137998
#           RNA Pol III                                                        0.117320
#           RNA exosome                                                        0.172466
#           SCF (exclusive subunits)                                           0.244423
#           Base Excision Repair Complex                                       0.117569
#           Nuclear pore complex                                               0.128176
#           Nuclear pore complex (exclusive subunits)                          0.135329
#
#                                                             significant
# predictor Complex
# H3K9me3   ncPRC1.6 (exclusive subunits)                            True
#           ncPRC1.6                                                 True
#           SIN3A/B (exclusive subunits)                             True
#           PRC1                                                     True
#           CAF-1                                                    True
#           BHC                                                      True
#           HUSH                                                     True
#           SIN3A/B                                                  True
#           KAP1-SETDB1-DNMT1-ZNF304                                 True
#           SF3B                                                     True
#           INO80 (exclusive subunits)                               True
#           KAP1-HP1                                                 True
#           B-MYB-MuvB                                               True
#           SRCAP                                                    True
#           ORC                                                      True
#           B-MYB-MuvB (exclusive subunits)                          True
#           ASAP                                                     True
#           Integrator (exclusive subunits)                          True
#           THO                                                      True
#           Integrator                                               True
#           PRC1 (exclusive subunits)                                True
#           PR-DUB                                                   True
#           ncPRC1                                                  False
#           TREX                                                    False
#           40S Ribosomal subunit                                   False
#           ncPRC1.1                                                False
#           INO80                                                   False
#           Mediator                                                False
#           NuA4 (exclusive subunits)                               False
#           PRC2.1                                                  False
# ...                                                                 ...
# H3ac      Mitochondrial respiratory chain complex I               False
#           ncPRC1.1 (exclusive subunits)                           False
#           CKM                                                     False
#           mCRD-poly(A)-bridging complex                           False
#           TFIID (exclusive subunits)                              False
#           RNA Pol II (exclusive subunits)                         False
#           NSL (exclusive subunits)                                False
#           Base Excision Repair Complex (exclusive subunits)       False
#           VHL SCF-like                                            False
#           XPC (exclusive subunits)                                False
#           Fanconi Anemia                                          False
#           PRC2.1 (exclusive subunits)                             False
#           RNA Pol II                                              False
#           B-MYB-MuvB (exclusive subunits)                         False
#           CRL4-DDB2                                               False
#           CDCA5-PDS5-Cohesin                                      False
#           VCB                                                     False
#           SCF                                                     False
#           CRL4-DDB2 (exclusive subunits)                          False
#           Condensin II                                            False
#           B-WICH (exclusive subunits)                             False
#           PTW/PP1                                                 False
#           OST                                                     False
#           PTW/PP1 (exclusive subunits)                            False
#           RNA Pol III                                             False
#           RNA exosome                                             False
#           SCF (exclusive subunits)                                False
#           Base Excision Repair Complex                            False
#           Nuclear pore complex                                    False
#           Nuclear pore complex (exclusive subunits)               False
#
# [1818 rows x 25 columns]

# %%
curated_complexes
# Out:
#                     Complex         Gene label    Member identifier  \
# 6     40S Ribosomal subunit                FAU                  FAU
# 7     40S Ribosomal subunit  RPS10/RPS10-NUDT3                RPS10
# 8     40S Ribosomal subunit              RPS11                RPS11
# 9     40S Ribosomal subunit              RPS12                RPS12
# 10    40S Ribosomal subunit              RPS13                RPS13
# 11    40S Ribosomal subunit              RPS14                RPS14
# 12    40S Ribosomal subunit              RPS15                RPS15
# 13    40S Ribosomal subunit             RPS15A               RPS15A
# 14    40S Ribosomal subunit              RPS16                RPS16
# 15    40S Ribosomal subunit              RPS17                RPS17
# 16    40S Ribosomal subunit              RPS18                RPS18
# 17    40S Ribosomal subunit              RPS19                RPS19
# 18    40S Ribosomal subunit               RPS2                 RPS2
# 19    40S Ribosomal subunit              RPS20                RPS20
# 20    40S Ribosomal subunit              RPS23                RPS23
# 21    40S Ribosomal subunit              RPS24                RPS24
# 22    40S Ribosomal subunit              RPS25                RPS25
# 23    40S Ribosomal subunit             RPS27A               RPS27A
# 24    40S Ribosomal subunit              RPS28                RPS28
# 25    40S Ribosomal subunit              RPS29                RPS29
# 26    40S Ribosomal subunit               RPS3                 RPS3
# 27    40S Ribosomal subunit              RPS3A                RPS3A
# 28    40S Ribosomal subunit              RPS4X                RPS4X
# 29    40S Ribosomal subunit               RPS5                 RPS5
# 30    40S Ribosomal subunit               RPS6                 RPS6
# 31    40S Ribosomal subunit               RPS7                 RPS7
# 32    40S Ribosomal subunit               RPS8                 RPS8
# 33    40S Ribosomal subunit               RPS9                 RPS9
# 34    40S Ribosomal subunit               RPSA                 RPSA
# 0     40S Ribosomal subunit                NaN                RPS21
# ...                     ...                ...                  ...
# 1371             ncPRC1.3/5               WDR5                 WDR5
# 1372             ncPRC1.3/5               YAF2      YAF2_HUMAN|YAF2
# 1357             ncPRC1.3/5                NaN          CSK21_HUMAN
# 1358             ncPRC1.3/5                NaN           FBRS_HUMAN
# 1359             ncPRC1.3/5                NaN           FBSL_HUMAN
# 1360             ncPRC1.3/5                NaN          PCGF3_HUMAN
# 1361             ncPRC1.3/5                NaN          PCGF5_HUMAN
# 1362             ncPRC1.3/5                NaN                AUTS2
# 1363             ncPRC1.3/5                NaN                  CK2
# 1364             ncPRC1.3/5                NaN                DCAF7
# 1365             ncPRC1.3/5                NaN                 FBRS
# 1366             ncPRC1.3/5                NaN                PCGF3
# 1367             ncPRC1.3/5                NaN                PCGF5
# 1375               ncPRC1.6               E2F6      E2F6_HUMAN|E2F6
# 1376               ncPRC1.6              HDAC1    HDAC1_HUMAN|HDAC1
# 1377               ncPRC1.6              HDAC2    HDAC2_HUMAN|HDAC2
# 1378               ncPRC1.6            L3MBTL2  LMBL2_HUMAN|L3MBTL2
# 1379               ncPRC1.6            MAX (1)                  MAX
# 1380               ncPRC1.6            MAX (2)                  MAX
# 1381               ncPRC1.6            MGA (1)       MGAP_HUMAN|MGA
# 1382               ncPRC1.6            MGA (2)       MGAP_HUMAN|MGA
# 1383               ncPRC1.6              PCGF6    PCGF6_HUMAN|PCGF6
# 1384               ncPRC1.6              RING1   RING1_HUMAN|RING1A
# 1385               ncPRC1.6               RNF2   RING2_HUMAN|RING1B
# 1386               ncPRC1.6               RYBP      RYBP_HUMAN|RYBP
# 1387               ncPRC1.6              TFDP1     TFDP1_HUMAN|DP-1
# 1388               ncPRC1.6               WDR5           WDR5_HUMAN
# 1389               ncPRC1.6               YAF2      YAF2_HUMAN|YAF2
# 1373               ncPRC1.6                NaN                DCAF7
# 1374               ncPRC1.6                NaN                 WDR5
#
#                                                  Source
# 6                        uniprot_search:"40S Ribosomal"
# 7                        uniprot_search:"40S Ribosomal"
# 8                        uniprot_search:"40S Ribosomal"
# 9                        uniprot_search:"40S Ribosomal"
# 10                       uniprot_search:"40S Ribosomal"
# 11                       uniprot_search:"40S Ribosomal"
# 12                       uniprot_search:"40S Ribosomal"
# 13                       uniprot_search:"40S Ribosomal"
# 14                       uniprot_search:"40S Ribosomal"
# 15                       uniprot_search:"40S Ribosomal"
# 16                       uniprot_search:"40S Ribosomal"
# 17                       uniprot_search:"40S Ribosomal"
# 18                       uniprot_search:"40S Ribosomal"
# 19                       uniprot_search:"40S Ribosomal"
# 20                       uniprot_search:"40S Ribosomal"
# 21                       uniprot_search:"40S Ribosomal"
# 22                       uniprot_search:"40S Ribosomal"
# 23                       uniprot_search:"40S Ribosomal"
# 24                       uniprot_search:"40S Ribosomal"
# 25                       uniprot_search:"40S Ribosomal"
# 26                       uniprot_search:"40S Ribosomal"
# 27                       uniprot_search:"40S Ribosomal"
# 28                       uniprot_search:"40S Ribosomal"
# 29                       uniprot_search:"40S Ribosomal"
# 30                       uniprot_search:"40S Ribosomal"
# 31                       uniprot_search:"40S Ribosomal"
# 32                       uniprot_search:"40S Ribosomal"
# 33                       uniprot_search:"40S Ribosomal"
# 34                       uniprot_search:"40S Ribosomal"
# 0                        uniprot_search:"40S Ribosomal"
# ...                                                 ...
# 1371                     doi:10.1016/j.cell.2017.08.002
# 1372  epifactors:RING2-FBRS|doi:10.1016/j.cell.2017....
# 1357                              epifactors:RING2-FBRS
# 1358                              epifactors:RING2-FBRS
# 1359                              epifactors:RING2-FBRS
# 1360                              epifactors:RING2-FBRS
# 1361                              epifactors:RING2-FBRS
# 1362                     doi:10.1016/j.cell.2017.08.002
# 1363                     doi:10.1016/j.cell.2017.08.002
# 1364                     doi:10.1016/j.cell.2017.08.002
# 1365                     doi:10.1016/j.cell.2017.08.002
# 1366                     doi:10.1016/j.cell.2017.08.002
# 1367                     doi:10.1016/j.cell.2017.08.002
# 1375  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1376  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1377  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1378  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1379                     doi:10.1016/j.cell.2017.08.002
# 1380                     doi:10.1016/j.cell.2017.08.002
# 1381  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1382  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1383  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1384  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1385  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1386  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1387  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1388                           epifactors:RING2-L3MBTL2
# 1389  epifactors:RING2-L3MBTL2|doi:10.1016/j.cell.20...
# 1373                     doi:10.1016/j.cell.2017.08.002
# 1374                     doi:10.1016/j.cell.2017.08.002
#
# [1390 rows x 4 columns]

# %%
sorted_complexes = sorted(curated_complexes['Complex'].unique(), key=lambda x: x.lower())

# %%
curated_complexes_excel = curated_complexes.copy()
curated_complexes_excel = curated_complexes_excel.rename(columns={
    'Complex': 'Protein complex name',
    'Gene label': 'Our identifier',
    'Member identifier': 'Source identifier',
    'Source': 'Source'
})

curated_complexes_excel['Source'] = curated_complexes_excel['Source'].str.replace(';', '|')

# %%
sources = curated_complexes_excel['Source'].str.split('|', expand=True).stack()
sources = sources.str.partition(':')[0]
sources = sources.value_counts()

# %%
sources.sort_index()
# Out:
# corum             268
# doi               518
# ebi               805
# epifactors        375
# uniprot_search     89
# Name: 0, dtype: int64

# %%
import xlsxwriter
import re

output_excel_filename = os.path.join(OUTPUT_DIRECTORY, 'ptm-response-complexes.xlsx')
output_tsv_filename_template = os.path.join(OUTPUT_DIRECTORY, 'ptm-response-complexes.sheet.{}.tsv.gz')

writer = pd.ExcelWriter(output_excel_filename, engine='xlsxwriter')
workbook  = writer.book

format_header_level_two = workbook.add_format({'bold': True})
format_header_level_two.set_bottom(1) # add border
format_header_level_two.set_text_wrap()

format_header_level_one = workbook.add_format({'bold': True})
format_header_level_one.set_right(1) # add border
format_header_level_one.set_text_wrap()

format_header_level_two_corner = workbook.add_format({'bold': True})
# format_header_level_two_corner.set_shrink()
format_header_level_two_corner.set_right(1) # add border
format_header_level_two_corner.set_bottom(1) # add border
format_header_level_two_corner.set_text_wrap()

format_bold = workbook.add_format({'bold': True})

format_merged_left_header = workbook.add_format({
    'bold': True,
    'right': 1,
    'text_wrap': True,
    'align': 'center',
    'valign': 'vcenter',
    'bottom': 1,
})

format_border_bottom = workbook.add_format({
    'bottom': True,
})

legend_bg = '#f0f0f0'
format_legend = workbook.add_format({'bg_color': legend_bg})
format_bold_legend = workbook.add_format({'bold': True, 
                                          'bg_color': legend_bg})

format_bold_legend_bottom = workbook.add_format({'bold': True, 
                                                 'bottom': 1,
                                                 'align': 'center',
                                                 'left': 1,
                                                 'right': 1,
                                                 'top': 1,
                                                 'bg_color': legend_bg})

format_bold_legend_right = workbook.add_format({'bold': True, 
                                                'right': 1,
                                                'left': 1,
                                                'align': 'right',
                                                'bg_color': legend_bg})

format_legend_right = workbook.add_format({'bg_color': legend_bg, 'right': 1})

format_top = workbook.add_format({'top': 1})

format_bold_right = workbook.add_format({'bold': True})
format_bold_right.set_right(1)


# Format for groups - border
format_group_right_edge = workbook.add_format()
format_group_right_edge.set_right(1)


format_pct = workbook.add_format({'num_format': '0.00%'})
format_twodigits = workbook.add_format({'num_format': '0.00'})

conditional_format_options = {
  'type': '3_color_scale',
  'min_value': vmin,
  'max_value': vmax,
  'mid_value': 0,
  'min_type': 'num',
  'max_type': 'num',
  'mid_type': 'num',
  'min_color': blue,
  'mid_color': white,
  'max_color': red
}

## First sheet, curated complexdes

startrow = 1
complexes_list_sheet_name = 'Index of complexes'
complexes_worksheet = None

complexes_df_in_order_of_excel = []

for complex_ in sorted_complexes:
    info = curated_complexes_excel[curated_complexes_excel['Protein complex name'] == complex_]
    info = info.sort_values(by=['Our identifier', 'Source identifier'])
    complexes_df_in_order_of_excel.append(info)
    
    info_no_first_col = info.iloc(axis=1)[1:]
    
    info_no_first_col.to_excel(writer, sheet_name=complexes_list_sheet_name, 
                               startrow=startrow, startcol=1,
                               index=False, header=False)

    if complexes_worksheet is None:
        complexes_worksheet = writer.sheets[complexes_list_sheet_name]
        
    endrow = startrow + len(info) - 1
    
    # Complex name as merged column
    complexes_worksheet.merge_range(startrow, 0, endrow, 0, complex_, format_merged_left_header)
    complexes_worksheet.set_row(endrow, None, format_border_bottom)
    startrow += len(info)

# Make TSV version of complexes sheet
pd.concat(complexes_df_in_order_of_excel).to_csv(
    output_tsv_filename_template.format('01.index_of_complexes'), 
    index=False,
    sep='\t'
)

for i, colname in enumerate(curated_complexes_excel.columns):
    if i == 0:
        format_ = format_header_level_two_corner
    else:
        format_ = format_header_level_two
        
    complexes_worksheet.write_string(0, i, colname, format_)

complexes_worksheet.merge_range(2, 5, 2, 6, 'Sources', format_bold_legend_bottom)
for row, (source, desc) in enumerate([
    ('corum', 'CORUM database (https://mips.helmholtz-muenchen.de/corum/)'),
    ('doi', 'Publication specified by Digital Object Identifier'),
    ('ebi', 'EBI Complex Portal (https://www.ebi.ac.uk/complexportal/)'),
    ('epifactors', 'EpiFactors database (http://epifactors.autosome.ru/)')
], start=3):
    complexes_worksheet.write_string(row, 5, source, format_bold_legend_right)
    complexes_worksheet.write_string(row, 6, desc, format_legend_right)

complexes_worksheet.write_string(row+1, 5, '', format_top)
complexes_worksheet.write_string(row+1, 6, '', format_top)
    
complexes_worksheet.set_column(0, 0, 20)
complexes_worksheet.set_column(1, 1, 20)
complexes_worksheet.set_column(2, 2, 20)
complexes_worksheet.set_column(3, 3, 40)

# legend
complexes_worksheet.set_column(5, 5, 10)
complexes_worksheet.set_column(6, 6, 60)

complexes_worksheet.freeze_panes(1, 1)

for i, predictor in enumerate(tqdm(predictors), start=2):
    
    lr = enrichment_complexes.loc[predictor].copy()
    order = lr.sort_values(by='FDR').index
    
    lr = lr[['PValue', 'FDR', 'empirical_median', 'empirical_median_ci_left', 'empirical_median_ci_right', 'Direction', 'NGenes', 'mean_proteins', 'mean_significant']]
    lr = lr.reindex(order)
    
    lr = lr.rename(columns={'NGenes': '# proteins', 
                            'Direction': 'Effect direction',
                            'PValue': 'P value',
                            'FDR': 'Adjusted P value (BH)',
                            'empirical_median': 'Median effect',
                            'empirical_median_ci_left': 'Median effect (95% CI left)',
                            'empirical_median_ci_right': 'Median effect (95% CI right)',
                            'mean_proteins': 'Proteins for which response was measurable',
                            'mean_significant': '% significantly enriched proteins'
                            })
    
    lr['# proteins'] = lr['# proteins'].fillna(0).astype(int)
    
    output_df = lr.reset_index()
    
    
    first_row_data = 1
    last_row_data = first_row_data + len(output_df)  - 1
    # Write main data
    output_df.to_excel(writer, 
                       sheet_name=predictor, 
                       startrow=first_row_data,
                       index=False, header=False)
   
    # Also save data as TSV
    output_df.to_csv(output_tsv_filename_template.format(
        '{:02}.{}'.format(
            i,
            re.sub('[^a-z0-9]+', '_', predictor.lower())
        )),
        sep='\t', index=False,
    )
    worksheet = writer.sheets[predictor]
       
    first_col = 0
    last_col = len(output_df.columns) - 1
    
    # Write columns (second level headers)
    for i, col in enumerate(output_df.columns):
        if i == 0:
            format_ = format_header_level_two_corner
        else:
            format_ = format_header_level_two
            
        worksheet.write_string(0, i, col, format_)
        
    col_effect = list(lr.columns).index('Median effect') + 1
    col_effect_ci_left = list(lr.columns).index('Median effect (95% CI left)') + 1
    col_effect_ci_right = list(lr.columns).index('Median effect (95% CI right)') + 1
    
    col_p_value = list(lr.columns).index('Adjusted P value (BH)') + 1
    col_mean_significant = list(lr.columns).index('% significantly enriched proteins') + 1
    
    col_complex = 0
    col_proteins = list(lr.columns).index('Proteins for which response was measurable') + 1
    
    col_p_value_letter = xlsxwriter.utility.xl_col_to_name(col_p_value)
    
    worksheet.set_column(first_col, last_col, 10)
    worksheet.set_column(col_mean_significant, col_mean_significant, 10, format_pct)
    worksheet.set_column(col_complex, col_complex, 30)
    worksheet.set_column(col_proteins, col_proteins, 50)
    
#     worksheet.set_row(0, 0, 5)
    
    for col in [col_effect, col_effect_ci_left, col_effect_ci_right]:
        worksheet.set_column(col, col, 10, format_twodigits)
    
    for col in [col_effect, col_effect_ci_left, col_effect_ci_right]:
        worksheet.conditional_format(first_row_data, col,
                                     last_row_data, col, 
                                     conditional_format_options)
    
    worksheet.conditional_format(first_row_data, col_complex, 
                                  last_row_data, col_complex, 
                                 {
                                     'type':     'formula',
                                     'criteria': '=${}{} <= {}'.format(col_p_value_letter, first_row_data+1, ENRICHMENT_FDR_THRESHOLD),
                                     'format':   format_bold
                                 })
    
    worksheet.conditional_format(first_row_data, col_p_value, last_row_data, col_p_value, 
                                 {'type':     'cell',
                                 'criteria': 'less than or equal to',
                                 'value':    ENRICHMENT_FDR_THRESHOLD,
                                 'format':   format_bold})
    
    worksheet.freeze_panes(first_row_data, 1)
    worksheet.autofilter(first_row_data-1, 0, last_row_data, last_col)
    


writer.save()
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 25.54it/s]
